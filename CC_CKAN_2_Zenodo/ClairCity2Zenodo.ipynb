# %%
# This script downloads datasets from claircitydata.cbs.nl and uploads it to the Zenodo ClairCity community.
# It supposes that the ClairCity community has been created already.
# For simplicity, datasets are hardcoded for now.
import requests
import json
import ckanapi
import datetime
import os

# %%
# Globals:
today = datetime.date.today().strftime("%Y%m%d")
claircitydataAPIkey = '73b4f80f-6ddf-4ae6-977b-afabd1a0a986'
ZenodoToken = 'GRSdtkiD3kGINZOgkVsOM5SZaS9B9vsUP1Z1Ln3l64ZqZH1s4TY2T3IyX6AW'
headers = {"Content-Type": "application/json"}
datasets = [
    {
        'claircitydataname': 'd5-5-assessment-of-impacts-first-city',
        'zenodoname': 'd5-5-assessment-of-impacts-bristol'
    }
#     {
#         'claircitydataname': 'd5-5d-assessment-of-impacts-cira',
#         'zenodoname': 'd5-5d-assessment-of-impacts-cira'
#     }   
]
version = '0.1.4'

# %%
# Get datasets from claircitydata.cbs.nl :
metadatafile = today + '/metadata.jsonl' 
if not os.path.exists(today):
    os.makedirs(today)

for dataset in datasets:
    name = dataset['claircitydataname']
    folder = today + '/' + name
    if not os.path.exists(folder):
        os.makedirs(folder)
    
    metadatafile = folder + '/metadata.jsonl'
    # !ckanapi dump datasets {name} -O {metadatafile} -r https://claircitydata.cbs.nl   
    #!ckanapi dump datasets {name} -O {metadatafile} -a {claircitydataAPIkey} -r https://claircitydata.cbs.nl

    with open(metadatafile, 'r', encoding='utf8') as json_file:
        
        jsonl = json.load(json_file)
        
        datafolder = folder + '/data'
        if not os.path.exists(datafolder):
            os.makedirs(datafolder)

        for resource in jsonl['resources']:

            filename = datafolder + '/' + resource['url'].split("/")[-1]
            # make unique if exists, which happens with files from Techne:
            if (os.path.exists(filename)):
                filename = datafolder + '/1_' + resource['url'].split("/")[-1]
                print(resource['name']+' duplicate renamed into: ' + filename)
            
            url = resource['url']
            r = requests.get(url, allow_redirects=True)            
            open(filename, 'wb').write(r.content)
            print(str(r.status_code) + ': ' + filename)
    
    json_file.close()
# Out:
# 0 [None] --- None d5-5-assessment-of-impacts-first-city
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/d5.5-assessment-of-impacts-first-city_final-002.pdf
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/170907_module-specs.pdf
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/bristol_200mx200m.rar
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/bristol_household_projections.xlsx
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/bristol_hh_energy_use_2025.xlsx
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/bristol_hh_energy_use_2035.xlsx
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/bristol_hh_energy_use_2050.xlsx
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/claircity_naturalemissions_brs_jan2019.pdf
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/claircity_agricultureemissions_brs_jan2019.pdf
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/fr1a-wp5-irc-first-city-bristol.pdf
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_baseline_not_industry_area_fuel_cons.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_baseline_not_industry_area_emi.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_baseline_industry_area_emi.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_baseline_industry_point_emi.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/fr3a-wp5-irc-future-first-city-bristol.pdf
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_bau_not_industry_area_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_bau_not_industry_area_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_bau_not_industry_area_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_bau_industry_area_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_bau_industry_area_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_bau_industry_area_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_bau_industry_point_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_bau_industry_point_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_bau_industry_point_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s1_not_industry_area_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s1_not_industry_area_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s1_not_industry_area_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s1_industry_area_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s1_industry_area_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s1_industry_area_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s1_industry_point_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s1_industry_point_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s1_industry_point_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s2_not_industry_area_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s2_not_industry_area_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s2_not_industry_area_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s2_industry_area_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s2_industry_area_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s2_industry_area_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s2_industry_point_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s2_industry_point_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s2_industry_point_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s3_not_industry_area_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s3_not_industry_area_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s3_not_industry_area_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s3_industry_area_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s3_industry_area_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s3_industry_area_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s3_industry_point_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s3_industry_point_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_s3_industry_point_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_ups_not_industry_area_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_ups_not_industry_area_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_ups_not_industry_area_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_ups_industry_point_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_ups_industry_point_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_ups_industry_point_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_ups_industry_area_emi_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_ups_industry_area_emi_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/2_brs_irci_ups_industry_area_emi_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/baseline_map_v3.zip
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/baseline_emissions_v3.zip
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/190919_behavior_v6_2015is1.xlsx
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/190219_bristol_scenario_results_pw_summary.xlsx
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/bristol-daily_hourlytd_res_comm_emi.xlsx
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/no2_2010010100_2010123123_lcc.png
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/pm10_2010010100_2010123123_lcc.png
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/3_brs_air-quality_baselinemesoscale-pm10-source-apportionment.xlsx
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/3_brs_air-quality_baselinemesoscale-pm2.5_concentrations_annual.png
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/brs_no2.mat
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/brs_pm10.mat
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/brs_pm2.mat
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/brs_no2_latlong.rar
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/brs_pm10_latlong.rar
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/brs_pm2_latlong.rar
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/brs_mesoscale.docx
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/brs_summary-aq-results.pptx
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/4_brs_aq2health_no2_baseline.mat
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/4_brs_aq2health_no2_bau.mat
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/4_brs_aq2health_no2_fups.mat
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/4_brs_aq2health_pm2_baseline.mat
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/4_brs_aq2health_pm2_bau.mat
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/4_brs_aq2health_pm2_fups.mat
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/4_brs_aq2health_pm10_baseline.mat
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/4_brs_aq2health_pm10_bau.mat
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/4_brs_aq2health_pm10_fups.mat
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/summary_results_hia_brs.xlsx
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/fr4a-wp5-carbon-footprint-future-first-city-bristol.pdf
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/181002_cf_bristol_summary_v2.xlsx
# 6_BRS_Carbon Footprint_BAU_Scenarios duplicate renamed into: 20191219/d5-5-assessment-of-impacts-first-city/data/1_fr4a-wp5-carbon-footprint-future-first-city-bristol.pdf
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/1_fr4a-wp5-carbon-footprint-future-first-city-bristol.pdf
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_bau_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_bau_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_bau_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_s1_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_s1_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_s1_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_s2_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_s2_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_s2_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_s3_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_s3_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_s3_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_ups_2025.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_ups_2035.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/6_brs_carbon-footprint_ups_2050.csv
# 200: 20191219/d5-5-assessment-of-impacts-first-city/data/190204_cf_bristol_summary_withfupsv3.xlsx

# %%
# Create Zenodo datasets:
for dataset in datasets:
    zenodoname = dataset['zenodoname']
    url = "https://zenodo.org/api/deposit/depositions"
    params = {'access_token': ZenodoToken}
    
    # Get metadata from claircitydata jsonl file:
    basepath = './'+today+'/'+dataset['claircitydataname']
    filename = basepath +'/metadata.jsonl'
    with open(filename, 'r', encoding='utf8') as json_file:
        metadataOld = json.load(json_file)
    json_file.close()
    
    # Define metadata for Zenodo:
    fileDescriptions = '<ul>'
    for resource in metadataOld["resources"]:
        filename = resource["url"].split("/")[-1]
        descr = resource['description'] if "description" in resource else ''
        fileDescriptions += '<li>'+ resource['name'] + '<br/>' + 'file: ' + filename + '<br/>' + descr +'</li>'
    fileDescriptions += '</ul>'
    
    keywords = []
    for tag in metadataOld["tags"]:
        keywords.append(tag['display_name'])
        
    metadataNew = {
        "metadata": {
            "upload_type": "dataset",
            "title": zenodoname,
            "description": metadataOld["notes"] + fileDescriptions,
            "license": metadataOld["license_id"],
            "keywords": keywords,
            "communities": [{'identifier':'claircity'}],
            "grants": [{'id':'689289'}],
            "version": version,
            "language": 'eng',
            "creators": [
                {'name':'Lopes, Myriam', 'affiliation': 'UAVR'},
                {'name':'Borrego, Carlos', 'affiliation': 'UAVR'},
                {'name': 'Rodrigues, Vera', 'affiliation': 'UAVR'},
                {'name': 'Coelho, Sílvia', 'affiliation': 'UAVR'},
                {'name': 'Faria, Carlos', 'affiliation': 'UAVR'},
                {'name': 'Rafael, Sandra', 'affiliation': 'UAVR'},
                {'name': 'Ferreira, Joana', 'affiliation': 'UAVR'},
                {'name': 'Fernandes, Ana Patrícia', 'affiliation': 'UAVR'},
                {'name': 'Vanherle, Kris', 'affiliation': 'TML'},
                {'name': 'Kewo, Angreine', 'affiliation': 'DTU'},
                {'name': 'Sieverts, Per', 'affiliation': 'DTU'},
                {'name': 'Knudsen, Svein', 'affiliation': 'NILU'},
                {'name': 'Thorne, Rebecca Jayne', 'affiliation': 'NILU'},
                {'name': 'Trozzi, Carlo', 'affiliation': 'Techne'},
                {'name': 'Diafas, Iason', 'affiliation': 'PBL'}
            ]
        }
    }
    
    #Do an update or a create:
    r = requests.get(url, params={'q': zenodoname, 'access_token': ZenodoToken})
    if (r.json()):
        print('Update: ' + zenodoname)
        deposition_id = str(r.json()[0]['id'])
        urlId = url + '/' + deposition_id
        r = requests.put(urlId, params=params, data=json.dumps(metadataNew), headers=headers)
    else:
        print('Create: ' + zenodoname)
        r = requests.post(url, params=params, data=json.dumps(metadataNew), headers=headers)
        deposition_id = str(r.json()['id'])

    # Add the files:
    #urlAddFile = url + '/' + deposition_id + '/files'
    #for resource in metadataOld["resources"]:

    #    filename = resource["url"].split("/")[-1]
    #    resourcename = resource["name"]
    #    data = {'name': resourcename} 
    #    files = {'file': open(basepath+'/data/'+filename, 'rb')}

    #    r = requests.post(urlAddFile, params=params, data=data, files=files)
    #    print(str(r.status_code) + ': ' + data['name'])
# Out:
# Update: d5-5-assessment-of-impacts-bristol
